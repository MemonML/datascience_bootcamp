# %% [markdown]
# <a href="https://colab.research.google.com/github/MemonML/datascience_bootcamp/blob/main/day_14_naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title: Naive Bayes Classifier
# Class: Week04-Day14
# Date: 09-08-2023

# %%
# Lab Task Bayes Theorem

# %%
# importing the dataset digits from sklearn
from sklearn.datasets import load_digits
digits = load_digits()
print(type(digits))
# print(digits)
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
# import numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Image Dataset", digits.data.shape)
# Out:
# Image Dataset (1797, 64)

# %%
first_image = digits.data[0,:]

# %%
x = digits.data

# %%
# print first image
print(first_image)
# Out:
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]

# %%
plt.figure(figsize=(10,4))
plt.imshow(np.reshape(first_image, (8,8)), cmap=plt.cm.gray)

# %% [markdown]
# # Visualizing Dataset

# %%
plt.figure(figsize=(30,7))
for index, (image, label) in enumerate(zip(digits.data[0:5], digits.target[0:5])):
    plt.subplot(1, 5, index + 1)
    plt.imshow(np.reshape(image, (8,8)), cmap=plt.cm.gray)
    plt.title('Training: %i\n' % label, fontsize = 40)

# %% [markdown]
# # Spliting Dataset

# %%
# spliting dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.2, random_state=42)

# %%
# print the shape of x_train
print(X_train.shape)
# Out:
# (1437, 64)

# %%
# print the shape of x_test
print(X_test.shape)
# Out:
# (360, 64)

# %%
# checking shape of y_test
y_test.shape
# Out:
# (360,)

# %% [markdown]
# # Training

# %%
# import naive bayes classifier
from sklearn.naive_bayes import GaussianNB
# assgin this model into classifier
classifier = GaussianNB()
# fit the model
classifier.fit(X_train, y_train)

#prediction
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
# confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square=True, cmap='Pastel1')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %%
from sklearn import naive_bayes
import joblib
joblib.dump(classifier,"/content/drive/MyDrive/Data_Science_Boot_Camp/week4/day_14/Digit_Classification_naive_bayes")
# Out:
# ['/content/drive/MyDrive/Data_Science_Boot_Camp/week4/day_14/Digit_Classification_naive_bayes']
