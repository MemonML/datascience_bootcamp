# %% [markdown]
# <a href="https://colab.research.google.com/github/MemonML/datascience_bootcamp/blob/main/Overfitting_Underfitting_analysis_for_non_parametric_classifiers_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overfitting (High Variance) Example for Decision Tree Classifier

# %%
# synthetic classification dataset
from sklearn.datasets import make_classification
# define dataset
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=13)
# summarize the dataset
print(X.shape, y.shape)
# Out:
# (10000, 20) (10000,)

# %%
from sklearn.model_selection import train_test_split
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# summarize the shape of the train and test sets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7000, 20) (3000, 20) (7000,) (3000,)

# %%
# define the tree depths to evaluate
depth_values = [i for i in range(1, 41)]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
# evaluate a decision tree for each depth
test_scores= []
train_scores=[]
for i in depth_values:
	# configure the model
	model = DecisionTreeClassifier(max_depth=i)
	# fit model on the training dataset
	model.fit(X_train, y_train)
	# evaluate on the train dataset
	train_yhat = model.predict(X_train)
	train_acc = metrics.accuracy_score(y_train, train_yhat)
	train_scores.append(train_acc)
	# evaluate on the test dataset
	test_yhat = model.predict(X_test)
	test_acc = metrics.accuracy_score(y_test, test_yhat)
	test_scores.append(test_acc)
	# summarize progress
	print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# Out:
# >1, train: 0.685, test: 0.675
# >2, train: 0.757, test: 0.756
# >3, train: 0.790, test: 0.787
# >4, train: 0.839, test: 0.826
# >5, train: 0.879, test: 0.866
# >6, train: 0.909, test: 0.881
# >7, train: 0.933, test: 0.889
# >8, train: 0.950, test: 0.891
# >9, train: 0.965, test: 0.895
# >10, train: 0.977, test: 0.890
# >11, train: 0.987, test: 0.890
# >12, train: 0.990, test: 0.890
# >13, train: 0.992, test: 0.886
# >14, train: 0.994, test: 0.890
# >15, train: 0.996, test: 0.879
# >16, train: 0.998, test: 0.882
# >17, train: 0.999, test: 0.884
# >18, train: 1.000, test: 0.879
# >19, train: 1.000, test: 0.877
# >20, train: 1.000, test: 0.875
# >21, train: 1.000, test: 0.880
# >22, train: 1.000, test: 0.877
# >23, train: 1.000, test: 0.877
# >24, train: 1.000, test: 0.881
# >25, train: 1.000, test: 0.876
# >26, train: 1.000, test: 0.883
# >27, train: 1.000, test: 0.882
# >28, train: 1.000, test: 0.886
# >29, train: 1.000, test: 0.875
# >30, train: 1.000, test: 0.884
# >31, train: 1.000, test: 0.883
# >32, train: 1.000, test: 0.880
# >33, train: 1.000, test: 0.878
# >34, train: 1.000, test: 0.878
# >35, train: 1.000, test: 0.881
# >36, train: 1.000, test: 0.882
# >37, train: 1.000, test: 0.880
# >38, train: 1.000, test: 0.883
# >39, train: 1.000, test: 0.882
# >40, train: 1.000, test: 0.878

# %%
from matplotlib import pyplot
pyplot.plot(depth_values, train_scores, '-o', label='Train')
pyplot.plot(depth_values, test_scores, '-o', label='Test')
pyplot.legend()
pyplot.show()

# %%
from sklearn.tree import export_graphviz,plot_tree
plot_tree(model)
# Out:
# [Text(0.4730823343704246, 0.975, 'x[17] <= -0.088\ngini = 0.5\nsamples = 7000\nvalue = [3466, 3534]'),
#  Text(0.20850629741780913, 0.925, 'x[5] <= -1.29\ngini = 0.432\nsamples = 3420\nvalue = [2340, 1080]'),
#  Text(0.07352256089444963, 0.875, 'x[15] <= 0.377\ngini = 0.455\nsamples = 770\nvalue = [269, 501]'),
#  Text(0.036736323705577, 0.825, 'x[10] <= 1.009\ngini = 0.31\nsamples = 484\nvalue = [93, 391]'),
#  Text(0.017037135631571942, 0.775, 'x[16] <= -5.333\ngini = 0.182\nsamples = 355\nvalue = [36, 319]'),
#  Text(0.008518567815785971, 0.725, 'x[14] <= -1.111\ngini = 0.49\nsamples = 35\nvalue = [20, 15]'),
#  Text(0.004259283907892986, 0.675, 'x[1] <= -1.355\ngini = 0.34\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.002129641953946493, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.006388925861839478, 0.625, 'x[10] <= 0.864\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.004259283907892986, 0.575, 'x[8] <= -3.725\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.002129641953946493, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.006388925861839478, 0.525, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.008518567815785971, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012777851723678957, 0.675, 'x[0] <= -3.592\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.010648209769732464, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01490749367762545, 0.625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.025555703447357914, 0.725, 'x[3] <= -2.275\ngini = 0.095\nsamples = 320\nvalue = [16, 304]'),
#  Text(0.021296419539464928, 0.675, 'x[17] <= -0.618\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.019166777585518435, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.02342606149341142, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.0298149873552509, 0.675, 'x[7] <= -6.333\ngini = 0.069\nsamples = 308\nvalue = [11, 297]'),
#  Text(0.027685345401304406, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03194462930919739, 0.625, 'x[17] <= -5.668\ngini = 0.063\nsamples = 307\nvalue = [10, 297]'),
#  Text(0.0298149873552509, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.034074271263143885, 0.575, 'x[5] <= -1.65\ngini = 0.057\nsamples = 306\nvalue = [9, 297]'),
#  Text(0.025555703447357914, 0.525, 'x[4] <= -4.8\ngini = 0.023\nsamples = 255\nvalue = [3, 252]'),
#  Text(0.021296419539464928, 0.475, 'x[3] <= -0.68\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.019166777585518435, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02342606149341142, 0.425, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.0298149873552509, 0.475, 'x[19] <= -4.922\ngini = 0.008\nsamples = 242\nvalue = [1, 241]'),
#  Text(0.027685345401304406, 0.425, 'x[19] <= -5.002\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.025555703447357914, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.0298149873552509, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03194462930919739, 0.425, 'gini = 0.0\nsamples = 237\nvalue = [0, 237]'),
#  Text(0.042592839078929856, 0.525, 'x[7] <= -0.463\ngini = 0.208\nsamples = 51\nvalue = [6, 45]'),
#  Text(0.03833355517103687, 0.475, 'x[2] <= 1.51\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.03620391321709038, 0.425, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.04046319712498336, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.04685212298682284, 0.475, 'x[17] <= -0.179\ngini = 0.051\nsamples = 38\nvalue = [1, 37]'),
#  Text(0.04472248103287635, 0.425, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
#  Text(0.048981764940769335, 0.425, 'x[12] <= -0.025\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04685212298682284, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05111140689471583, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05643551177958206, 0.775, 'x[14] <= 0.81\ngini = 0.493\nsamples = 129\nvalue = [57, 72]'),
#  Text(0.05111140689471583, 0.725, 'x[19] <= 1.523\ngini = 0.331\nsamples = 62\nvalue = [49, 13]'),
#  Text(0.048981764940769335, 0.675, 'x[3] <= 4.089\ngini = 0.14\nsamples = 53\nvalue = [49, 4]'),
#  Text(0.04685212298682284, 0.625, 'x[7] <= -5.228\ngini = 0.075\nsamples = 51\nvalue = [49, 2]'),
#  Text(0.04472248103287635, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.048981764940769335, 0.575, 'x[18] <= 4.327\ngini = 0.039\nsamples = 50\nvalue = [49, 1]'),
#  Text(0.04685212298682284, 0.525, 'gini = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.05111140689471583, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05111140689471583, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05324104884866232, 0.675, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.06175961666444829, 0.725, 'x[12] <= -1.174\ngini = 0.21\nsamples = 67\nvalue = [8, 59]'),
#  Text(0.057500332756555306, 0.675, 'x[13] <= 1.615\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.05537069080260881, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.0596299747105018, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06601890057234128, 0.675, 'x[16] <= 9.914\ngini = 0.033\nsamples = 59\nvalue = [1, 58]'),
#  Text(0.06388925861839478, 0.625, 'gini = 0.0\nsamples = 58\nvalue = [0, 58]'),
#  Text(0.06814854252628777, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11030879808332224, 0.825, 'x[8] <= 0.024\ngini = 0.473\nsamples = 286\nvalue = [176, 110]'),
#  Text(0.0970983628377479, 0.775, 'x[14] <= 2.095\ngini = 0.307\nsamples = 195\nvalue = [158, 37]'),
#  Text(0.08664980700119793, 0.725, 'x[3] <= 1.702\ngini = 0.202\nsamples = 158\nvalue = [140, 18]'),
#  Text(0.07853054705177692, 0.675, 'x[10] <= -4.67\ngini = 0.152\nsamples = 145\nvalue = [133, 12]'),
#  Text(0.07240782643418076, 0.625, 'x[19] <= -3.573\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07027818448023426, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07453746838812725, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08465326766937309, 0.625, 'x[9] <= -3.782\ngini = 0.121\nsamples = 139\nvalue = [130, 9]'),
#  Text(0.07879675229602023, 0.575, 'x[12] <= 0.223\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07666711034207374, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08092639424996673, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.09050978304272594, 0.575, 'x[14] <= -4.642\ngini = 0.098\nsamples = 136\nvalue = [129, 7]'),
#  Text(0.08518567815785971, 0.525, 'x[10] <= 0.403\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08305603620391322, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0873153201118062, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09583388792759218, 0.525, 'x[0] <= -4.809\ngini = 0.072\nsamples = 133\nvalue = [128, 5]'),
#  Text(0.09157460401969919, 0.475, 'x[11] <= -0.751\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0894449620657527, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09370424597364568, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10009317183548516, 0.475, 'x[14] <= 1.125\ngini = 0.045\nsamples = 130\nvalue = [127, 3]'),
#  Text(0.09796352988153867, 0.425, 'gini = 0.0\nsamples = 109\nvalue = [109, 0]'),
#  Text(0.10222281378943165, 0.425, 'x[12] <= 0.835\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.10009317183548516, 0.375, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.10435245574337815, 0.375, 'x[11] <= -1.965\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.10222281378943165, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10648209769732464, 0.325, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09476906695061893, 0.675, 'x[8] <= -1.946\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.09263942499667244, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.09689870890456542, 0.625, 'x[4] <= 1.105\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.09476906695061893, 0.575, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.09902835085851192, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10754691867429789, 0.725, 'x[16] <= 5.224\ngini = 0.5\nsamples = 37\nvalue = [18, 19]'),
#  Text(0.1032876347664049, 0.675, 'x[19] <= 0.315\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.10115799281245841, 0.625, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.1054172767203514, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11180620258219087, 0.675, 'x[2] <= 4.758\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.10967656062824438, 0.625, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.11393584453613737, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12351923332889658, 0.775, 'x[3] <= -1.413\ngini = 0.317\nsamples = 91\nvalue = [18, 73]'),
#  Text(0.11819512844403035, 0.725, 'x[4] <= -0.408\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.11606548649008386, 0.675, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.12032477039797684, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12884333821376281, 0.725, 'x[1] <= -0.242\ngini = 0.182\nsamples = 79\nvalue = [8, 71]'),
#  Text(0.12458405430586983, 0.675, 'x[0] <= -1.633\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.12245441235192334, 0.625, 'x[14] <= 2.216\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.12032477039797684, 0.575, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.12458405430586983, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.12671369625981632, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.1331026221216558, 0.675, 'x[14] <= -3.858\ngini = 0.031\nsamples = 63\nvalue = [1, 62]'),
#  Text(0.1309729801677093, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1352322640756023, 0.625, 'gini = 0.0\nsamples = 62\nvalue = [0, 62]'),
#  Text(0.3434900339411686, 0.875, 'x[14] <= 1.874\ngini = 0.342\nsamples = 2650\nvalue = [2071, 579]'),
#  Text(0.2247146612538267, 0.825, 'x[2] <= -6.704\ngini = 0.236\nsamples = 2048\nvalue = [1768, 280]'),
#  Text(0.14162118993744177, 0.775, 'x[12] <= -3.46\ngini = 0.353\nsamples = 35\nvalue = [8, 27]'),
#  Text(0.13949154798349528, 0.725, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.14375083189138826, 0.725, 'x[5] <= 3.033\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.14162118993744177, 0.675, 'x[1] <= 0.508\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.13949154798349528, 0.625, 'x[13] <= 5.725\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13736190602954879, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14162118993744177, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14375083189138826, 0.625, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.14588047384533476, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3078081325702116, 0.775, 'x[7] <= 1.143\ngini = 0.22\nsamples = 2013\nvalue = [1760, 253]'),
#  Text(0.2577033142552908, 0.725, 'x[11] <= 3.15\ngini = 0.154\nsamples = 1622\nvalue = [1486, 136]'),
#  Text(0.20391321709037669, 0.675, 'x[14] <= 1.03\ngini = 0.26\nsamples = 624\nvalue = [528, 96]'),
#  Text(0.16398243045387995, 0.625, 'x[9] <= -1.749\ngini = 0.211\nsamples = 550\nvalue = [484, 66]'),
#  Text(0.14588047384533476, 0.575, 'x[12] <= 1.168\ngini = 0.497\nsamples = 37\nvalue = [20, 17]'),
#  Text(0.14162118993744177, 0.525, 'x[10] <= -0.162\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.13949154798349528, 0.475, 'x[6] <= -5.223\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.13736190602954879, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14162118993744177, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14375083189138826, 0.475, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.15013975775322774, 0.525, 'x[3] <= -1.663\ngini = 0.346\nsamples = 18\nvalue = [4, 14]'),
#  Text(0.14801011579928125, 0.475, 'x[11] <= 2.554\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.14588047384533476, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.15013975775322774, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15226939970717424, 0.475, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.18208438706242513, 0.575, 'x[11] <= -2.972\ngini = 0.173\nsamples = 513\nvalue = [464, 49]'),
#  Text(0.1607879675229602, 0.525, 'x[3] <= -0.914\ngini = 0.427\nsamples = 42\nvalue = [29, 13]'),
#  Text(0.15652868361506722, 0.475, 'x[15] <= -0.137\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.15439904166112073, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15865832556901371, 0.425, 'x[19] <= -3.461\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.15652868361506722, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1607879675229602, 0.375, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.1650472514308532, 0.475, 'x[12] <= -1.976\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.1629176094769067, 0.425, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.16717689338479969, 0.425, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.20338080660189006, 0.525, 'x[12] <= 2.482\ngini = 0.141\nsamples = 471\nvalue = [435, 36]'),
#  Text(0.1858112604818315, 0.475, 'x[6] <= 9.589\ngini = 0.11\nsamples = 412\nvalue = [388, 24]'),
#  Text(0.183681618527885, 0.425, 'x[4] <= -0.958\ngini = 0.106\nsamples = 411\nvalue = [388, 23]'),
#  Text(0.1650472514308532, 0.375, 'x[1] <= 1.235\ngini = 0.05\nsamples = 234\nvalue = [228, 6]'),
#  Text(0.15706109410355384, 0.325, 'x[16] <= 8.367\ngini = 0.028\nsamples = 209\nvalue = [206, 3]'),
#  Text(0.1517369892186876, 0.275, 'x[9] <= -1.407\ngini = 0.019\nsamples = 204\nvalue = [202, 2]'),
#  Text(0.14747770531079463, 0.225, 'x[7] <= -0.542\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.14534806335684813, 0.175, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.14960734726474112, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1559962731265806, 0.225, 'x[14] <= 0.747\ngini = 0.01\nsamples = 198\nvalue = [197, 1]'),
#  Text(0.1538666311726341, 0.175, 'gini = 0.0\nsamples = 188\nvalue = [188, 0]'),
#  Text(0.1581259150805271, 0.175, 'x[14] <= 0.775\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.1559962731265806, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16025555703447358, 0.125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.16238519898842008, 0.275, 'x[13] <= -1.051\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.16025555703447358, 0.225, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.16451484094236657, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17303340875815254, 0.325, 'x[10] <= -1.085\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.17090376680420605, 0.275, 'x[3] <= -1.755\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.16877412485025955, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17303340875815254, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.17516305071209903, 0.275, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.20231598562491682, 0.375, 'x[7] <= 0.878\ngini = 0.174\nsamples = 177\nvalue = [160, 17]'),
#  Text(0.19326500732064422, 0.325, 'x[6] <= -3.178\ngini = 0.136\nsamples = 163\nvalue = [151, 12]'),
#  Text(0.1815519765739385, 0.275, 'x[14] <= -1.455\ngini = 0.375\nsamples = 32\nvalue = [24, 8]'),
#  Text(0.17729269266604553, 0.225, 'x[19] <= -4.463\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.17516305071209903, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17942233461999202, 0.175, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.1858112604818315, 0.225, 'x[15] <= -0.89\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.183681618527885, 0.175, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.187940902435778, 0.175, 'x[1] <= -1.047\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.1858112604818315, 0.125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.19007054438972448, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.20497803806734993, 0.275, 'x[17] <= -0.13\ngini = 0.059\nsamples = 131\nvalue = [127, 4]'),
#  Text(0.20284839611340344, 0.225, 'x[5] <= -0.675\ngini = 0.045\nsamples = 130\nvalue = [127, 3]'),
#  Text(0.19645947025156396, 0.175, 'x[7] <= -2.531\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.19432982829761747, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19858911220551045, 0.125, 'x[5] <= -0.701\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.19645947025156396, 0.075, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.20071875415945695, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20923732197524292, 0.175, 'x[7] <= -3.936\ngini = 0.017\nsamples = 116\nvalue = [115, 1]'),
#  Text(0.20710768002129643, 0.125, 'x[12] <= 0.313\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.20497803806734993, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20923732197524292, 0.075, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2113669639291894, 0.125, 'gini = 0.0\nsamples = 110\nvalue = [110, 0]'),
#  Text(0.20710768002129643, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2113669639291894, 0.325, 'x[11] <= -0.613\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.20923732197524292, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2134966058831359, 0.275, 'x[16] <= -1.53\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.2113669639291894, 0.225, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.2156262478370824, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.187940902435778, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22095035272194863, 0.475, 'x[1] <= -3.02\ngini = 0.324\nsamples = 59\nvalue = [47, 12]'),
#  Text(0.2156262478370824, 0.425, 'x[19] <= -2.193\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2134966058831359, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2177558897910289, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.22627445760681486, 0.425, 'x[3] <= 0.257\ngini = 0.252\nsamples = 54\nvalue = [46, 8]'),
#  Text(0.22201517369892187, 0.375, 'x[11] <= 3.065\ngini = 0.208\nsamples = 51\nvalue = [45, 6]'),
#  Text(0.21988553174497538, 0.325, 'x[6] <= -5.222\ngini = 0.18\nsamples = 50\nvalue = [45, 5]'),
#  Text(0.2177558897910289, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22201517369892187, 0.275, 'x[9] <= -1.479\ngini = 0.15\nsamples = 49\nvalue = [45, 4]'),
#  Text(0.21988553174497538, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22414481565286837, 0.225, 'x[5] <= 4.279\ngini = 0.117\nsamples = 48\nvalue = [45, 3]'),
#  Text(0.22201517369892187, 0.175, 'x[3] <= -3.66\ngini = 0.081\nsamples = 47\nvalue = [45, 2]'),
#  Text(0.2177558897910289, 0.125, 'x[1] <= -0.716\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2156262478370824, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21988553174497538, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22627445760681486, 0.125, 'x[7] <= 0.613\ngini = 0.043\nsamples = 45\nvalue = [44, 1]'),
#  Text(0.22414481565286837, 0.075, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(0.22840409956076135, 0.075, 'x[16] <= -3.525\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.22627445760681486, 0.025, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.23053374151470785, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22627445760681486, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22414481565286837, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23053374151470785, 0.375, 'x[13] <= -1.915\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.22840409956076135, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23266338346865434, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.24384400372687343, 0.625, 'x[15] <= 0.451\ngini = 0.482\nsamples = 74\nvalue = [44, 30]'),
#  Text(0.23266338346865434, 0.575, 'x[12] <= -0.772\ngini = 0.43\nsamples = 32\nvalue = [10, 22]'),
#  Text(0.2273392785837881, 0.525, 'x[3] <= 1.342\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.22520963662984161, 0.475, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.2294689205377346, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23798748835352057, 0.525, 'x[6] <= 3.325\ngini = 0.227\nsamples = 23\nvalue = [3, 20]'),
#  Text(0.23372820444562759, 0.475, 'x[14] <= 1.842\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.2315985624916811, 0.425, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.23585784639957408, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24224677226141356, 0.475, 'x[4] <= -2.062\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.24011713030746706, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.24437641421536005, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2550246239850925, 0.575, 'x[13] <= 2.426\ngini = 0.308\nsamples = 42\nvalue = [34, 8]'),
#  Text(0.24863569812325303, 0.525, 'x[0] <= 2.89\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(0.24650605616930654, 0.475, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.25076534007719953, 0.475, 'x[18] <= -0.34\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.24863569812325303, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.252894982031146, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.261413549846932, 0.525, 'x[7] <= -1.798\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.2592839078929855, 0.475, 'x[2] <= 0.662\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.257154265939039, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.261413549846932, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2635431918008785, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.311493411420205, 0.675, 'x[1] <= 3.517\ngini = 0.077\nsamples = 998\nvalue = [958, 40]'),
#  Text(0.3022095035272195, 0.625, 'x[19] <= 4.094\ngini = 0.07\nsamples = 992\nvalue = [956, 36]'),
#  Text(0.29003061360308796, 0.575, 'x[10] <= -3.139\ngini = 0.065\nsamples = 987\nvalue = [954, 33]'),
#  Text(0.27206175961666446, 0.525, 'x[2] <= 1.423\ngini = 0.32\nsamples = 35\nvalue = [28, 7]'),
#  Text(0.26780247570877147, 0.475, 'x[16] <= 3.06\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.265672833754825, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.26993211766271796, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.27632104352455744, 0.475, 'x[14] <= 1.791\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.27419140157061095, 0.425, 'x[0] <= -2.903\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.27206175961666446, 0.375, 'x[11] <= 6.226\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26993211766271796, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.27419140157061095, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27632104352455744, 0.375, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.27845068547850393, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3079994675895115, 0.525, 'x[17] <= -0.215\ngini = 0.053\nsamples = 952\nvalue = [926, 26]'),
#  Text(0.29708505257553575, 0.475, 'x[14] <= 0.224\ngini = 0.042\nsamples = 923\nvalue = [903, 20]'),
#  Text(0.28803407427126315, 0.425, 'x[15] <= 4.458\ngini = 0.013\nsamples = 619\nvalue = [615, 4]'),
#  Text(0.2827099693863969, 0.375, 'x[12] <= -1.678\ngini = 0.01\nsamples = 614\nvalue = [611, 3]'),
#  Text(0.27845068547850393, 0.325, 'x[19] <= -3.684\ngini = 0.056\nsamples = 70\nvalue = [68, 2]'),
#  Text(0.27632104352455744, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2805803274324504, 0.275, 'x[12] <= -1.681\ngini = 0.029\nsamples = 69\nvalue = [68, 1]'),
#  Text(0.27845068547850393, 0.225, 'gini = 0.0\nsamples = 68\nvalue = [68, 0]'),
#  Text(0.2827099693863969, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2869692532942899, 0.325, 'x[15] <= 1.871\ngini = 0.004\nsamples = 544\nvalue = [543, 1]'),
#  Text(0.2848396113403434, 0.275, 'gini = 0.0\nsamples = 495\nvalue = [495, 0]'),
#  Text(0.2890988952482364, 0.275, 'x[15] <= 1.906\ngini = 0.04\nsamples = 49\nvalue = [48, 1]'),
#  Text(0.2869692532942899, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2912285372021829, 0.225, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(0.2933581791561294, 0.375, 'x[19] <= -3.293\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2912285372021829, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2954878211100759, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.30613603087980834, 0.425, 'x[14] <= 0.251\ngini = 0.1\nsamples = 304\nvalue = [288, 16]'),
#  Text(0.30400638892586185, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.30826567283375483, 0.375, 'x[18] <= 1.295\ngini = 0.083\nsamples = 301\nvalue = [288, 13]'),
#  Text(0.29974710501796886, 0.325, 'x[1] <= 0.591\ngini = 0.037\nsamples = 262\nvalue = [257, 5]'),
#  Text(0.29761746306402237, 0.275, 'gini = 0.0\nsamples = 213\nvalue = [213, 0]'),
#  Text(0.30187674697191536, 0.275, 'x[17] <= -2.422\ngini = 0.183\nsamples = 49\nvalue = [44, 5]'),
#  Text(0.29974710501796886, 0.225, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.30400638892586185, 0.225, 'x[19] <= 0.337\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.30187674697191536, 0.175, 'x[17] <= -2.203\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.29974710501796886, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30400638892586185, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.30613603087980834, 0.175, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3167842406495408, 0.325, 'x[17] <= -1.929\ngini = 0.326\nsamples = 39\nvalue = [31, 8]'),
#  Text(0.3146545986955943, 0.275, 'x[5] <= 0.067\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(0.3125249567416478, 0.225, 'x[18] <= 1.906\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3103953147877013, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3146545986955943, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3167842406495408, 0.225, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.3189138826034873, 0.275, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3189138826034873, 0.475, 'x[15] <= 0.314\ngini = 0.328\nsamples = 29\nvalue = [23, 6]'),
#  Text(0.3146545986955943, 0.425, 'x[17] <= -0.195\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.3125249567416478, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3167842406495408, 0.375, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.3231731665113803, 0.425, 'x[5] <= 1.057\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.3210435245574338, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3253028084653268, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.314388393451351, 0.575, 'x[3] <= 1.211\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.3122587514974045, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3165180354052975, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3207773193131905, 0.625, 'x[14] <= 0.617\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.318647677359244, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.32290696126713697, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3579129508851324, 0.725, 'x[16] <= -4.233\ngini = 0.419\nsamples = 391\nvalue = [274, 117]'),
#  Text(0.3346199920138427, 0.675, 'x[9] <= -3.767\ngini = 0.147\nsamples = 200\nvalue = [184, 16]'),
#  Text(0.32929588712897645, 0.625, 'x[0] <= 0.221\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.32716624517502996, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.33142552908292294, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3399440968987089, 0.625, 'x[8] <= -4.324\ngini = 0.116\nsamples = 195\nvalue = [183, 12]'),
#  Text(0.33568481299081593, 0.575, 'x[10] <= -0.713\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.33355517103686944, 0.525, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3378144549447624, 0.525, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3442033808066019, 0.575, 'x[10] <= 3.916\ngini = 0.063\nsamples = 183\nvalue = [177, 6]'),
#  Text(0.3420737388526554, 0.525, 'x[6] <= -6.638\ngini = 0.053\nsamples = 182\nvalue = [177, 5]'),
#  Text(0.3399440968987089, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3442033808066019, 0.475, 'x[1] <= 5.129\ngini = 0.043\nsamples = 181\nvalue = [177, 4]'),
#  Text(0.3399440968987089, 0.425, 'x[8] <= -2.84\ngini = 0.033\nsamples = 179\nvalue = [176, 3]'),
#  Text(0.3378144549447624, 0.375, 'x[14] <= -1.613\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.33568481299081593, 0.325, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.3399440968987089, 0.325, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3420737388526554, 0.375, 'gini = 0.0\nsamples = 160\nvalue = [160, 0]'),
#  Text(0.3484626647144949, 0.425, 'x[5] <= 0.289\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3463330227605484, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3505923066684414, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3463330227605484, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3812059097564222, 0.675, 'x[5] <= 1.35\ngini = 0.498\nsamples = 191\nvalue = [90, 101]'),
#  Text(0.36603221083455345, 0.625, 'x[15] <= 1.273\ngini = 0.426\nsamples = 117\nvalue = [36, 81]'),
#  Text(0.3559164115533076, 0.575, 'x[4] <= -2.37\ngini = 0.304\nsamples = 91\nvalue = [17, 74]'),
#  Text(0.3505923066684414, 0.525, 'x[9] <= -0.628\ngini = 0.48\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.3484626647144949, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.35272194862238787, 0.475, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.36124051643817384, 0.525, 'x[10] <= 0.542\ngini = 0.188\nsamples = 76\nvalue = [8, 68]'),
#  Text(0.35698123253028086, 0.475, 'x[12] <= 2.594\ngini = 0.032\nsamples = 61\nvalue = [1, 60]'),
#  Text(0.35485159057633436, 0.425, 'gini = 0.0\nsamples = 60\nvalue = [0, 60]'),
#  Text(0.35911087448422735, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3654998003460668, 0.475, 'x[19] <= -0.048\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.36337015839212033, 0.425, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.3676294423000133, 0.425, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.3761480101157993, 0.575, 'x[4] <= 0.691\ngini = 0.393\nsamples = 26\nvalue = [19, 7]'),
#  Text(0.3718887262079063, 0.525, 'x[13] <= 4.959\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.3697590842539598, 0.475, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.3740183681618528, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3804072940236923, 0.525, 'x[11] <= 7.124\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.3782776520697458, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.38253693597763877, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.396379608678291, 0.625, 'x[7] <= 3.72\ngini = 0.394\nsamples = 74\nvalue = [54, 20]'),
#  Text(0.3942499667243445, 0.575, 'x[1] <= -2.425\ngini = 0.327\nsamples = 68\nvalue = [54, 14]'),
#  Text(0.38892586183947825, 0.525, 'x[15] <= 1.748\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.38679621988553176, 0.475, 'x[17] <= -2.334\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.38466657793158526, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38892586183947825, 0.425, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.39105550379342474, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3995740716092107, 0.525, 'x[12] <= 2.498\ngini = 0.215\nsamples = 57\nvalue = [50, 7]'),
#  Text(0.3953147877013177, 0.475, 'x[3] <= -3.318\ngini = 0.111\nsamples = 51\nvalue = [48, 3]'),
#  Text(0.39318514574737123, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3974444296552642, 0.425, 'x[17] <= -0.155\ngini = 0.077\nsamples = 50\nvalue = [48, 2]'),
#  Text(0.3953147877013177, 0.375, 'x[10] <= -2.525\ngini = 0.04\nsamples = 49\nvalue = [48, 1]'),
#  Text(0.39318514574737123, 0.325, 'x[6] <= -0.375\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.39105550379342474, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3953147877013177, 0.275, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3974444296552642, 0.325, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
#  Text(0.3995740716092107, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4038333555171037, 0.475, 'x[17] <= -1.162\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4017037135631572, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4059629974710502, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.39850925063223747, 0.575, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.46226540662851057, 0.825, 'x[16] <= 1.49\ngini = 0.5\nsamples = 602\nvalue = [303, 299]'),
#  Text(0.4363103953147877, 0.775, 'x[15] <= 1.08\ngini = 0.303\nsamples = 311\nvalue = [58, 253]'),
#  Text(0.4240649540795954, 0.725, 'x[5] <= 4.546\ngini = 0.169\nsamples = 236\nvalue = [22, 214]'),
#  Text(0.41661120724078265, 0.675, 'x[17] <= -4.567\ngini = 0.123\nsamples = 228\nvalue = [15, 213]'),
#  Text(0.4080926394249967, 0.625, 'x[6] <= 9.007\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.4059629974710502, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4102222813789432, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4251297750565686, 0.625, 'x[12] <= 0.598\ngini = 0.094\nsamples = 222\nvalue = [11, 211]'),
#  Text(0.41448156528683616, 0.575, 'x[3] <= -1.771\ngini = 0.423\nsamples = 23\nvalue = [7, 16]'),
#  Text(0.4102222813789432, 0.525, 'x[7] <= 0.932\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.4080926394249967, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.41235192333288967, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41874084919472915, 0.525, 'x[17] <= -0.374\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.41661120724078265, 0.475, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.42087049114867564, 0.475, 'x[12] <= 0.3\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.41874084919472915, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42300013310262213, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4357779848263011, 0.575, 'x[15] <= 0.615\ngini = 0.039\nsamples = 199\nvalue = [4, 195]'),
#  Text(0.4315187009184081, 0.525, 'x[1] <= -2.518\ngini = 0.011\nsamples = 179\nvalue = [1, 178]'),
#  Text(0.4293890589644616, 0.475, 'x[5] <= -0.485\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.4272594170105151, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4315187009184081, 0.425, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.4336483428723546, 0.475, 'gini = 0.0\nsamples = 170\nvalue = [0, 170]'),
#  Text(0.4400372687341941, 0.525, 'x[19] <= -1.337\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.4379076267802476, 0.475, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.44216691068814057, 0.475, 'x[10] <= -3.162\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4400372687341941, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44429655264208706, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4315187009184081, 0.675, 'x[9] <= -2.747\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4293890589644616, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4336483428723546, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.44855583654998005, 0.725, 'x[19] <= -1.84\ngini = 0.499\nsamples = 75\nvalue = [36, 39]'),
#  Text(0.44429655264208706, 0.675, 'x[14] <= 2.446\ngini = 0.198\nsamples = 36\nvalue = [4, 32]'),
#  Text(0.44216691068814057, 0.625, 'x[15] <= 2.382\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.4400372687341941, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.44429655264208706, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.44642619459603355, 0.625, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.45281512045787303, 0.675, 'x[18] <= 2.215\ngini = 0.295\nsamples = 39\nvalue = [32, 7]'),
#  Text(0.45068547850392654, 0.625, 'x[2] <= -3.998\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.44855583654998005, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.45281512045787303, 0.575, 'x[0] <= -4.909\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.45068547850392654, 0.525, 'x[8] <= 0.798\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.44855583654998005, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45281512045787303, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4549447624118195, 0.525, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.4549447624118195, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4882204179422335, 0.775, 'x[7] <= 1.436\ngini = 0.266\nsamples = 291\nvalue = [245, 46]'),
#  Text(0.47890323439371757, 0.725, 'x[1] <= 2.226\ngini = 0.219\nsamples = 279\nvalue = [244, 35]'),
#  Text(0.46665779315852524, 0.675, 'x[11] <= -1.918\ngini = 0.155\nsamples = 260\nvalue = [238, 22]'),
#  Text(0.4592040463197125, 0.625, 'x[15] <= 2.375\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.457074404365766, 0.575, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.461333688273659, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.47411153999733796, 0.625, 'x[7] <= -0.972\ngini = 0.119\nsamples = 252\nvalue = [236, 16]'),
#  Text(0.465592972181552, 0.575, 'x[14] <= 2.082\ngini = 0.048\nsamples = 205\nvalue = [200, 5]'),
#  Text(0.461333688273659, 0.525, 'x[5] <= -0.127\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.4592040463197125, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4634633302276055, 0.475, 'x[8] <= 3.508\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.461333688273659, 0.425, 'x[14] <= 2.073\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.4592040463197125, 0.375, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.4634633302276055, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.465592972181552, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.469852256089445, 0.525, 'x[12] <= 5.526\ngini = 0.011\nsamples = 184\nvalue = [183, 1]'),
#  Text(0.4677226141354985, 0.475, 'gini = 0.0\nsamples = 183\nvalue = [183, 0]'),
#  Text(0.47198189804339147, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.48263010781312393, 0.575, 'x[15] <= 0.96\ngini = 0.359\nsamples = 47\nvalue = [36, 11]'),
#  Text(0.47837082390523095, 0.525, 'x[8] <= -1.198\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.47624118195128445, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.48050046585917744, 0.475, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.4868893917210169, 0.525, 'x[8] <= 2.068\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.4847597497670704, 0.475, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.4890190336749634, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4911486756289099, 0.675, 'x[5] <= 1.729\ngini = 0.432\nsamples = 19\nvalue = [6, 13]'),
#  Text(0.4890190336749634, 0.625, 'x[16] <= 6.265\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.4868893917210169, 0.575, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.4911486756289099, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4932783175828564, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4975376014907494, 0.725, 'x[10] <= -4.373\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.4954079595368029, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4996672434446959, 0.675, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.73765837132304, 0.925, 'x[3] <= -0.516\ngini = 0.431\nsamples = 3580\nvalue = [1126, 2454]'),
#  Text(0.5968581541993877, 0.875, 'x[9] <= -0.202\ngini = 0.477\nsamples = 1267\nvalue = [770, 497]'),
#  Text(0.5541062158924531, 0.825, 'x[19] <= -0.373\ngini = 0.432\nsamples = 454\nvalue = [143, 311]'),
#  Text(0.5302808465326767, 0.775, 'x[10] <= -0.761\ngini = 0.5\nsamples = 235\nvalue = [114, 121]'),
#  Text(0.513509916145348, 0.725, 'x[2] <= 7.4\ngini = 0.367\nsamples = 132\nvalue = [32, 100]'),
#  Text(0.5039265273525888, 0.675, 'x[12] <= -2.779\ngini = 0.194\nsamples = 101\nvalue = [11, 90]'),
#  Text(0.5017968853986423, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5060561693065353, 0.625, 'x[3] <= -2.827\ngini = 0.15\nsamples = 98\nvalue = [8, 90]'),
#  Text(0.4996672434446959, 0.575, 'x[4] <= -1.559\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.4975376014907494, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5017968853986423, 0.525, 'x[18] <= -1.417\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.4996672434446959, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5039265273525888, 0.475, 'x[12] <= -1.102\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.5017968853986423, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5060561693065353, 0.425, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.5124450951683748, 0.575, 'x[4] <= -5.033\ngini = 0.052\nsamples = 75\nvalue = [2, 73]'),
#  Text(0.5103154532144283, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5145747371223213, 0.525, 'x[18] <= -3.035\ngini = 0.027\nsamples = 74\nvalue = [1, 73]'),
#  Text(0.5124450951683748, 0.475, 'x[5] <= 1.576\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5103154532144283, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5145747371223213, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5167043790762678, 0.475, 'gini = 0.0\nsamples = 71\nvalue = [0, 71]'),
#  Text(0.5230933049381072, 0.675, 'x[9] <= -1.968\ngini = 0.437\nsamples = 31\nvalue = [21, 10]'),
#  Text(0.5188340210302143, 0.625, 'x[10] <= -2.737\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5167043790762678, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5209636629841607, 0.575, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5273525888460002, 0.625, 'x[15] <= 0.127\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.5252229468920537, 0.575, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5294822307999467, 0.575, 'x[10] <= -3.627\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.5273525888460002, 0.525, 'x[15] <= 1.201\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5252229468920537, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5294822307999467, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5316118727538932, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5470517769200053, 0.725, 'x[14] <= 0.368\ngini = 0.325\nsamples = 103\nvalue = [82, 21]'),
#  Text(0.5411952615466524, 0.675, 'x[18] <= 0.698\ngini = 0.215\nsamples = 90\nvalue = [79, 11]'),
#  Text(0.5358711566617862, 0.625, 'x[19] <= -0.496\ngini = 0.031\nsamples = 63\nvalue = [62, 1]'),
#  Text(0.5337415147078397, 0.575, 'gini = 0.0\nsamples = 59\nvalue = [59, 0]'),
#  Text(0.5380007986157327, 0.575, 'x[7] <= 1.295\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5358711566617862, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5401304405696792, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5465193664315187, 0.625, 'x[9] <= -3.13\ngini = 0.466\nsamples = 27\nvalue = [17, 10]'),
#  Text(0.5443897244775722, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5486490083854652, 0.575, 'x[17] <= 1.348\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.5443897244775722, 0.525, 'x[8] <= -4.205\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.5422600825236257, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5465193664315187, 0.475, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.5529082922933581, 0.525, 'x[15] <= 0.382\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.5507786503394116, 0.475, 'x[14] <= -0.926\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5486490083854652, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5529082922933581, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5550379342473046, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5529082922933581, 0.675, 'x[18] <= -3.086\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.5507786503394116, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5550379342473046, 0.625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.5779315852522294, 0.775, 'x[7] <= -1.489\ngini = 0.23\nsamples = 219\nvalue = [29, 190]'),
#  Text(0.5688806069479568, 0.725, 'x[1] <= -0.464\ngini = 0.497\nsamples = 39\nvalue = [21, 18]'),
#  Text(0.5635565020630906, 0.675, 'x[4] <= -1.423\ngini = 0.355\nsamples = 26\nvalue = [20, 6]'),
#  Text(0.5592972181551976, 0.625, 'x[0] <= -5.608\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.5571675762012511, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5614268601091441, 0.575, 'x[12] <= 7.336\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.5592972181551976, 0.525, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.5635565020630906, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5678157859709836, 0.625, 'x[13] <= 4.752\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.5656861440170371, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5699454279249301, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5742047118328231, 0.675, 'x[10] <= 1.122\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.5720750698788766, 0.625, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.5763343537867696, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.586982563556502, 0.725, 'x[17] <= 0.161\ngini = 0.085\nsamples = 180\nvalue = [8, 172]'),
#  Text(0.582723279648609, 0.675, 'x[5] <= 3.463\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.5805936376946625, 0.625, 'x[3] <= -0.841\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.578463995740716, 0.575, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.582723279648609, 0.575, 'x[14] <= -1.862\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5805936376946625, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5848529216025555, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5848529216025555, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.591241847464395, 0.675, 'x[8] <= -1.653\ngini = 0.036\nsamples = 164\nvalue = [3, 161]'),
#  Text(0.5891122055104485, 0.625, 'x[7] <= 0.365\ngini = 0.191\nsamples = 28\nvalue = [3, 25]'),
#  Text(0.586982563556502, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.591241847464395, 0.575, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.5933714894183415, 0.625, 'gini = 0.0\nsamples = 136\nvalue = [0, 136]'),
#  Text(0.6396100925063224, 0.825, 'x[14] <= 0.104\ngini = 0.353\nsamples = 813\nvalue = [627, 186]'),
#  Text(0.614372587514974, 0.775, 'x[2] <= -3.196\ngini = 0.178\nsamples = 577\nvalue = [520, 57]'),
#  Text(0.6035205643551178, 0.725, 'x[12] <= -1.849\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.6013909224011713, 0.675, 'x[18] <= -0.546\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.5992612804472248, 0.625, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.6035205643551178, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6056502063090643, 0.675, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.6252246106748303, 0.725, 'x[0] <= 1.066\ngini = 0.133\nsamples = 544\nvalue = [505, 39]'),
#  Text(0.617280047916944, 0.675, 'x[19] <= 1.554\ngini = 0.095\nsamples = 499\nvalue = [474, 25]'),
#  Text(0.6077798482630108, 0.625, 'x[4] <= 4.554\ngini = 0.075\nsamples = 484\nvalue = [465, 19]'),
#  Text(0.5994276587248769, 0.575, 'x[1] <= -5.768\ngini = 0.068\nsamples = 481\nvalue = [464, 17]'),
#  Text(0.5891122055104485, 0.525, 'x[8] <= -0.622\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
# ...
#  Text(0.7540263543191801, 0.275, 'gini = 0.0\nsamples = 865\nvalue = [0, 865]'),
#  Text(0.7582856382270731, 0.275, 'x[2] <= 5.254\ngini = 0.038\nsamples = 103\nvalue = [2, 101]'),
#  Text(0.7561559962731266, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7604152801810196, 0.225, 'x[0] <= -2.422\ngini = 0.019\nsamples = 102\nvalue = [1, 101]'),
#  Text(0.7582856382270731, 0.175, 'x[19] <= -0.966\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.7561559962731266, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7604152801810196, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.762544922134966, 0.175, 'gini = 0.0\nsamples = 93\nvalue = [0, 93]'),
#  Text(0.7646745640889125, 0.325, 'x[0] <= 6.018\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.762544922134966, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.766804206042859, 0.275, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.771063489950752, 0.375, 'x[9] <= -1.407\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.7689338479968055, 0.325, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.7731931319046985, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7774524158125915, 0.425, 'x[19] <= -4.749\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.775322773858645, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.779582057766538, 0.375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.783841341674431, 0.475, 'x[9] <= 0.715\ngini = 0.094\nsamples = 61\nvalue = [3, 58]'),
#  Text(0.7817116997204845, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7859709836283775, 0.425, 'x[2] <= 7.451\ngini = 0.064\nsamples = 60\nvalue = [2, 58]'),
#  Text(0.783841341674431, 0.375, 'x[15] <= 1.619\ngini = 0.033\nsamples = 59\nvalue = [1, 58]'),
#  Text(0.7817116997204845, 0.325, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(0.7859709836283775, 0.325, 'x[18] <= -1.365\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.783841341674431, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.788100625582324, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.788100625582324, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8044722481032877, 0.725, 'x[12] <= -1.451\ngini = 0.281\nsamples = 367\nvalue = [62, 305]'),
#  Text(0.788100625582324, 0.675, 'x[2] <= 0.722\ngini = 0.49\nsamples = 42\nvalue = [24, 18]'),
#  Text(0.7859709836283775, 0.625, 'x[19] <= -2.593\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.783841341674431, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.788100625582324, 0.575, 'x[12] <= -1.591\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.7859709836283775, 0.525, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.7902302675362705, 0.525, 'x[8] <= 1.736\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.788100625582324, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.792359909490217, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7902302675362705, 0.625, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.8208438706242513, 0.675, 'x[0] <= -1.428\ngini = 0.207\nsamples = 325\nvalue = [38, 287]'),
#  Text(0.8040729402369227, 0.625, 'x[16] <= -0.423\ngini = 0.471\nsamples = 58\nvalue = [22, 36]'),
#  Text(0.7966191933981099, 0.575, 'x[1] <= 0.208\ngini = 0.363\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.7944895514441634, 0.525, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.7987488353520564, 0.525, 'x[17] <= 0.319\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7966191933981099, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8008784773060029, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8115266870757354, 0.575, 'x[9] <= 0.155\ngini = 0.272\nsamples = 37\nvalue = [6, 31]'),
#  Text(0.8072674031678424, 0.525, 'x[14] <= -2.69\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.8051377612138959, 0.475, 'x[5] <= 1.041\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8030081192599494, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8072674031678424, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8093970451217889, 0.475, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.8157859709836284, 0.525, 'x[6] <= 2.517\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.8136563290296819, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8179156129375749, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8376148010115799, 0.625, 'x[14] <= -3.547\ngini = 0.113\nsamples = 267\nvalue = [16, 251]'),
#  Text(0.8285638227073073, 0.575, 'x[7] <= 0.561\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.8243045387994143, 0.525, 'x[4] <= -1.608\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.8221748968454679, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8264341807533608, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8328231066152003, 0.525, 'x[16] <= -9.851\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.8306934646612538, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8349527485691468, 0.475, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.8466657793158525, 0.575, 'x[12] <= 0.792\ngini = 0.079\nsamples = 244\nvalue = [10, 234]'),
#  Text(0.844536137361906, 0.525, 'x[4] <= -2.753\ngini = 0.234\nsamples = 74\nvalue = [10, 64]'),
#  Text(0.8392120324770398, 0.475, 'x[9] <= 0.457\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.8370823905230933, 0.425, 'x[19] <= -0.312\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8349527485691468, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8392120324770398, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8413416744309863, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8498602422467723, 0.475, 'x[4] <= 4.964\ngini = 0.116\nsamples = 65\nvalue = [4, 61]'),
#  Text(0.8477306002928258, 0.425, 'x[11] <= 1.514\ngini = 0.089\nsamples = 64\nvalue = [3, 61]'),
#  Text(0.8434713163849328, 0.375, 'x[18] <= 2.154\ngini = 0.034\nsamples = 57\nvalue = [1, 56]'),
#  Text(0.8413416744309863, 0.325, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]'),
#  Text(0.8456009583388793, 0.325, 'x[19] <= 2.978\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8434713163849328, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8477306002928258, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8519898842007188, 0.375, 'x[15] <= 0.029\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8498602422467723, 0.325, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8541195261546652, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8519898842007188, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.848795421269799, 0.525, 'gini = 0.0\nsamples = 170\nvalue = [0, 170]'),
#  Text(0.8679621988553174, 0.775, 'x[1] <= -0.489\ngini = 0.494\nsamples = 132\nvalue = [59, 73]'),
#  Text(0.8594436310395315, 0.725, 'x[7] <= 1.646\ngini = 0.394\nsamples = 74\nvalue = [54, 20]'),
#  Text(0.8551843471316385, 0.675, 'x[6] <= -3.416\ngini = 0.038\nsamples = 52\nvalue = [51, 1]'),
#  Text(0.853054705177692, 0.625, 'x[4] <= -0.014\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8509250632237455, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8551843471316385, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.857313989085585, 0.625, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(0.8637029149474245, 0.675, 'x[19] <= -0.185\ngini = 0.236\nsamples = 22\nvalue = [3, 19]'),
#  Text(0.861573272993478, 0.625, 'x[1] <= -0.567\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8594436310395315, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8637029149474245, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.865832556901371, 0.625, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.8764807666711034, 0.725, 'x[17] <= 0.144\ngini = 0.158\nsamples = 58\nvalue = [5, 53]'),
#  Text(0.8722214827632104, 0.675, 'x[5] <= 1.502\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.8700918408092639, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8743511247171569, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8807400505789964, 0.675, 'x[19] <= -4.861\ngini = 0.041\nsamples = 48\nvalue = [1, 47]'),
#  Text(0.8786104086250499, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8828696925329429, 0.625, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.93970451217889, 0.825, 'x[2] <= 0.164\ngini = 0.476\nsamples = 499\nvalue = [195, 304]'),
#  Text(0.9023026753627047, 0.775, 'x[12] <= -2.484\ngini = 0.306\nsamples = 255\nvalue = [48, 207]'),
#  Text(0.8892586183947824, 0.725, 'x[2] <= -8.446\ngini = 0.444\nsamples = 42\nvalue = [28, 14]'),
#  Text(0.8871289764408359, 0.675, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8913882603487289, 0.675, 'x[7] <= 1.198\ngini = 0.291\nsamples = 34\nvalue = [28, 6]'),
#  Text(0.8871289764408359, 0.625, 'x[11] <= -7.006\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.8849993344868894, 0.575, 'x[2] <= -3.801\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8828696925329429, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8871289764408359, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8892586183947824, 0.575, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.8956475442566219, 0.625, 'x[0] <= -0.212\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8935179023026754, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8977771862105683, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9153467323306269, 0.725, 'x[15] <= 3.453\ngini = 0.17\nsamples = 213\nvalue = [20, 193]'),
#  Text(0.9132170903766804, 0.675, 'x[15] <= 0.155\ngini = 0.134\nsamples = 208\nvalue = [15, 193]'),
#  Text(0.9041661120724078, 0.625, 'x[8] <= -4.388\ngini = 0.027\nsamples = 148\nvalue = [2, 146]'),
#  Text(0.9020364701184613, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9062957540263543, 0.575, 'x[19] <= -4.409\ngini = 0.014\nsamples = 147\nvalue = [1, 146]'),
#  Text(0.9041661120724078, 0.525, 'x[17] <= 1.598\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9020364701184613, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9062957540263543, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9084253959803008, 0.525, 'gini = 0.0\nsamples = 144\nvalue = [0, 144]'),
#  Text(0.922268068680953, 0.625, 'x[10] <= 0.348\ngini = 0.339\nsamples = 60\nvalue = [13, 47]'),
#  Text(0.9169439637960868, 0.575, 'x[16] <= 9.08\ngini = 0.204\nsamples = 52\nvalue = [6, 46]'),
#  Text(0.9126846798881938, 0.525, 'x[9] <= 1.199\ngini = 0.15\nsamples = 49\nvalue = [4, 45]'),
#  Text(0.9105550379342473, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9148143218421403, 0.475, 'x[10] <= -1.314\ngini = 0.117\nsamples = 48\nvalue = [3, 45]'),
#  Text(0.9126846798881938, 0.425, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
#  Text(0.9169439637960868, 0.425, 'x[17] <= 1.771\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.9148143218421403, 0.375, 'x[16] <= 3.973\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.9126846798881938, 0.325, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9169439637960868, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9190736057500333, 0.375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.9212032477039798, 0.525, 'x[13] <= -9.387\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9190736057500333, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9233328896579263, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9275921735658192, 0.575, 'x[7] <= -5.522\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.9254625316118728, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9297218155197657, 0.525, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.9174763742845734, 0.675, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9771063489950752, 0.775, 'x[12] <= 1.09\ngini = 0.479\nsamples = 244\nvalue = [147, 97]'),
#  Text(0.9627312658059364, 0.725, 'x[7] <= 2.237\ngini = 0.359\nsamples = 158\nvalue = [121, 37]'),
#  Text(0.9552775189671237, 0.675, 'x[3] <= 2.87\ngini = 0.224\nsamples = 132\nvalue = [115, 17]'),
#  Text(0.9467589511513377, 0.625, 'x[14] <= -0.55\ngini = 0.184\nsamples = 127\nvalue = [114, 13]'),
#  Text(0.9361107413816052, 0.575, 'x[10] <= -3.735\ngini = 0.092\nsamples = 104\nvalue = [99, 5]'),
#  Text(0.9339810994276587, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9382403833355517, 0.525, 'x[2] <= 0.463\ngini = 0.057\nsamples = 102\nvalue = [99, 3]'),
#  Text(0.9339810994276587, 0.475, 'x[10] <= -1.639\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.9318514574737122, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9361107413816052, 0.425, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9424996672434447, 0.475, 'x[3] <= 2.711\ngini = 0.021\nsamples = 95\nvalue = [94, 1]'),
#  Text(0.9403700252894982, 0.425, 'gini = 0.0\nsamples = 91\nvalue = [91, 0]'),
#  Text(0.9446293091973912, 0.425, 'x[16] <= 1.104\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9424996672434447, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9467589511513377, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9574071609210701, 0.575, 'x[9] <= 2.739\ngini = 0.454\nsamples = 23\nvalue = [15, 8]'),
#  Text(0.9552775189671237, 0.525, 'x[2] <= 4.489\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.9510182350592307, 0.475, 'x[15] <= 2.385\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.9488885931052842, 0.425, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.9531478770131772, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9595368028750166, 0.475, 'x[1] <= -2.212\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9574071609210701, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9616664448289631, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9595368028750166, 0.525, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.9637960867829096, 0.625, 'x[9] <= 4.084\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.9616664448289631, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9659257287368561, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9701850126447491, 0.675, 'x[11] <= -2.316\ngini = 0.355\nsamples = 26\nvalue = [6, 20]'),
#  Text(0.9680553706908026, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9723146545986956, 0.625, 'x[10] <= 0.995\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.9701850126447491, 0.575, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.9744442965526421, 0.575, 'x[14] <= 0.09\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9723146545986956, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9765739385065886, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.991481432184214, 0.725, 'x[0] <= -1.297\ngini = 0.422\nsamples = 86\nvalue = [26, 60]'),
#  Text(0.987222148276321, 0.675, 'x[3] <= 3.255\ngini = 0.408\nsamples = 35\nvalue = [25, 10]'),
#  Text(0.9850925063223746, 0.625, 'x[19] <= 2.67\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.9829628643684281, 0.575, 'x[19] <= -2.762\ngini = 0.191\nsamples = 28\nvalue = [25, 3]'),
#  Text(0.9808332224144816, 0.525, 'x[8] <= -0.041\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.9787035804605351, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9829628643684281, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9850925063223746, 0.525, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.987222148276321, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9893517902302675, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.995740716092107, 0.675, 'x[9] <= 5.162\ngini = 0.038\nsamples = 51\nvalue = [1, 50]'),
#  Text(0.9936110741381605, 0.625, 'gini = 0.0\nsamples = 50\nvalue = [0, 50]'),
#  Text(0.9978703580460535, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %% [markdown]
# # Example of underfitting (High Bias) in KNN classification

# %%
# evaluate knn performance on train and test sets with different numbers of neighbors
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from matplotlib import pyplot
# create dataset
X, y = make_classification(n_samples=10000, n_features=100, n_classes=20, n_informative=15, n_redundant=5, random_state=13)
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# define lists to collect scores
train_scores, test_scores = list(), list()
# define the tree depths to evaluate
k_values = [i for i in range(1, 30)]
# evaluate a decision tree for each depth
for i in k_values:
	# configure the model
	model = KNeighborsClassifier(n_neighbors=i)
	# fit model on the training dataset
	model.fit(X_train, y_train)
	# evaluate on the train dataset
	train_yhat = model.predict(X_train)
	train_acc = accuracy_score(y_train, train_yhat)
	train_scores.append(train_acc)
	# evaluate on the test dataset
	test_yhat = model.predict(X_test)
	test_acc = accuracy_score(y_test, test_yhat)
	test_scores.append(test_acc)
	# summarize progress
	print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs number of neighbors
pyplot.plot(k_values, train_scores, '-o', label='Train')
pyplot.plot(k_values, test_scores, '-o', label='Test')
pyplot.legend()
pyplot.show()
# Out:
# >1, train: 1.000, test: 0.341
# >2, train: 0.672, test: 0.322
# >3, train: 0.639, test: 0.348
# >4, train: 0.638, test: 0.372
# >5, train: 0.629, test: 0.380
# >6, train: 0.628, test: 0.406
# >7, train: 0.618, test: 0.417
# >8, train: 0.607, test: 0.421
# >9, train: 0.597, test: 0.423
# >10, train: 0.590, test: 0.423
# >11, train: 0.593, test: 0.435
# >12, train: 0.581, test: 0.432
# >13, train: 0.580, test: 0.439
# >14, train: 0.577, test: 0.436
# >15, train: 0.577, test: 0.437
# >16, train: 0.575, test: 0.439
# >17, train: 0.572, test: 0.443
# >18, train: 0.569, test: 0.447
# >19, train: 0.565, test: 0.445
# >20, train: 0.563, test: 0.450
# >21, train: 0.558, test: 0.450
# >22, train: 0.560, test: 0.454
# >23, train: 0.557, test: 0.454
# >24, train: 0.553, test: 0.451
# >25, train: 0.550, test: 0.443
# >26, train: 0.546, test: 0.445
# >27, train: 0.544, test: 0.446
# >28, train: 0.545, test: 0.447
# >29, train: 0.540, test: 0.444

# %%
make_classification??

# %%
# For Decision Tree in figure (Not for KNN)
plot_tree(model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-b5dba0e757a6> in <cell line: 2>()
#       1 # For Decision Tree in figure (Not for KNN)
# ----> 2 plot_tree(model)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     192         fontsize=fontsize,
#     193     )
# --> 194     return exporter.export(decision_tree, ax=ax)
#     195
#     196
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     653         ax.clear()
#     654         ax.set_axis_off()
# --> 655         my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     656         draw_tree = buchheim(my_tree)
#     657
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'tree_'
